# %% [markdown]
# 本篇记录硬件实现`tanh算法`的探究

# %% [markdown]
# 首先是**CORDIC**在双曲空间下的算法，缺陷是
# - x范围只限制在-1.1到1.1之间，超出区域需要用到查表
# - 该算法略微复杂，需要特定位置的重复迭代保证收敛
#
# 详见[这篇](https://blog.csdn.net/Pieces_thinking/article/details/83545806)

# %% [markdown]
# 接着是21年IEEE的一篇文章**A Novel Configurable High-precision
# and Low-cost Circuit Design of
# Sigmoid and Tanh Activation Function**
# tanh的二阶分段近似是
# $$
# g(x) = \left\{
# \begin{array}{ll}
# 0 & \text{,} x<-4\\
# 2^{-1}(1+2^{-2}x)^2 & \text{,} -4 \leq x \leq 0\\
# 1-2^{-1}(1+2^{-2}x)^2 & \text{,} 0 \leq x <4\\
# 1 & \text{,} x \geq 4\\
# \end{array}
# \right.
# $$
# 使用python绘制差异曲线

# %%
import numpy as np
from pathlib import Path
from fixedpoint import FixedPoint
import matplotlib.pyplot as plt
import random
import pprint
def tanh_g(x):
    if(x<=-2):
        return -1
    elif(-2<x and x<0):
        return -1+(1+0.5*x)**2
    elif(0<=x and x<2):
        return 1-(1-0.5*x)**2
    else:
        return 1
def tanh_g_fix(x):
    x     =FixedPoint(x,signed=True,m=2,n=6,str_base=2,overflow='clamp',overflow_alert='ignore') 
    one   =FixedPoint(1,signed=True,m=1,n=7,str_base=2,overflow='clamp',overflow_alert='ignore')
    m_one =FixedPoint(-1,signed=True,m=1,n=7,str_base=2,overflow='clamp',overflow_alert='ignore')
    if(float(x)<-2):
        return m_one
    elif(-2<=float(x) and float(x)<0):
        return -1+(1+0.5*x)**2
    elif(0<=float(x) and float(x)<2):
        return 1-(1-0.5*x)**2
    else:
        return one    
x  = np.linspace(-5, 5, 400)
# 计算对应的 tanh(x) 值
y1 = np.tanh(x)
y2 = np.array([tanh_g(i) for i in x])
y3 = np.array([tanh_g_fix(i) for i in x])
plt.figure(figsize=(8, 6))
plt.plot(x, y1, color='blue')
plt.plot(x, y2, color='red')
plt.plot(x, y3, color='black')
plt.title('tanh')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# 接着是这篇**An FPGA-Based LSTM Acceleration Engine for Deep Learning Frameworks**的x+查找表的方法
# ![image.png](attachment:f46bb31e-f1a3-4dc6-94f7-0a0a31fa22d5.png)

# %% [markdown]
# 此方法依赖查找表，我们先生成256深度的查找表

# %%
import numpy as np
from fixedpoint import FixedPoint

# 定义常量
n_points = 256  # 256 个查找表点
x_min = 0.0     # 范围开始
x = 0.0
x_add = float(FixedPoint("0b00_0000_01", signed=True, m=2, n=6, str_base=2, overflow='clamp', overflow_alert='ignore'))
q_format = 8    # 定点格式 Q8.7

# 计算 tanh(x) 并将结果转换为 Q8.7 格式
lookup_table = []

# 打开文件以写入
with open("../output/mem_file/tanh_pos.txt", "w") as f:
    for i in range(n_points):
        # 计算 tanh(x)
        tanh_value = np.tanh(x)

        # 将 tanh(x) 转换为 Q8.7 定点数
        q8_7_value = FixedPoint(tanh_value, signed=True, m=8, n=7, str_base=2, overflow='clamp', overflow_alert='ignore')

        # 存储
        lookup_table.append((x, str(q8_7_value), float(q8_7_value), tanh_value))
        
        # 写入 val[1] (Q8.7 格式的字符串) 到文件
        f.write(f"{str(q8_7_value)}\n")

        # 计算当前 x 值
        x = x + x_add

# 输出查找表
print('-' * 70)
print(f"{'t a n h    t a b l e':^70}")
print('-' * 70)
print('\33[1;7;32m', end='')
print(f"{'addr':>5}  {'input':<10} {'tanh(FXP Q9.7)':>16} {'tanh(FXP)':<10} {'tanh(float ref)':<25}")
print('\33[0m', end='')

for i, val in enumerate(lookup_table):
    print(f"{i:5}  {val[0]:<10} {val[1]:>16} {val[2]:<10} {val[3]:<25}")

lst_hardtanh = [(elem[0],elem[0] if elem[0]<0.25 else elem[2]) for elem in lookup_table]
# Out:
# ----------------------------------------------------------------------
#                          t a n h    t a b l e
# ----------------------------------------------------------------------
#  addr  input        tanh(FXP Q9.7) tanh(FXP)  tanh(float ref)
#     0  0.0         000000000000000 0.0        0.0
#     1  0.015625    000000000000010 0.015625   0.015623728558408866
#     2  0.03125     000000000000100 0.03125    0.031239831446031256
#     3  0.046875    000000000000110 0.046875   0.04684069787264808
#     4  0.0625      000000000001000 0.0625     0.062418746747512514
#     5  0.078125    000000000001010 0.078125   0.07796644137536819
#     6  0.09375     000000000001100 0.09375    0.09347630396922774
#     7  0.109375    000000000001110 0.109375   0.10894092992085458
#     8  0.125       000000000010000 0.125      0.12435300177159621
#     9  0.140625    000000000010010 0.140625   0.13970530282831423
#    10  0.15625     000000000010100 0.15625    0.1549907303716235
# ...

# %%
import matplotlib.pyplot as plt
# 提取数据用于绘图
x_values = [elem[0] for elem in lookup_table]
tanh_values = [elem[3] for elem in lookup_table]  # tanh 函数的值
hardtanh_values = [elem[1] for elem in lst_hardtanh]  # hardtanh 函数的值

# 绘制图像
plt.figure(figsize=(5, 3))
plt.plot(x_values, tanh_values, label='tanh(x)', color='green', linestyle='-', linewidth=2)
plt.plot(x_values, hardtanh_values, label='hardtanh(x)', color='red', linestyle='--', linewidth=4)

# 添加标题和标签
plt.title('Comparison of tanh(x) and hardtanh(x)', fontsize=16)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(loc='upper left')

# 显示网格
plt.grid(True)

# 展示图像
plt.show()

# 计算并打印误差
print("Error between tanh(x) and hardtanh(x):")
for i in range(len(x_values)):
    error = abs(tanh_values[i] - hardtanh_values[i])
    print(f"x = {x_values[i]:.4f}, tanh(x) = {tanh_values[i]:.6f}, hardtanh(x) = {hardtanh_values[i]:.6f}, Error = {error:.6f}")
# Out:
# Error between tanh(x) and hardtanh(x):
# x = 0.0000, tanh(x) = 0.000000, hardtanh(x) = 0.000000, Error = 0.000000
# x = 0.0156, tanh(x) = 0.015624, hardtanh(x) = 0.015625, Error = 0.000001
# x = 0.0312, tanh(x) = 0.031240, hardtanh(x) = 0.031250, Error = 0.000010
# x = 0.0469, tanh(x) = 0.046841, hardtanh(x) = 0.046875, Error = 0.000034
# x = 0.0625, tanh(x) = 0.062419, hardtanh(x) = 0.062500, Error = 0.000081
# x = 0.0781, tanh(x) = 0.077966, hardtanh(x) = 0.078125, Error = 0.000159
# x = 0.0938, tanh(x) = 0.093476, hardtanh(x) = 0.093750, Error = 0.000274
# x = 0.1094, tanh(x) = 0.108941, hardtanh(x) = 0.109375, Error = 0.000434
# x = 0.1250, tanh(x) = 0.124353, hardtanh(x) = 0.125000, Error = 0.000647
# x = 0.1406, tanh(x) = 0.139705, hardtanh(x) = 0.140625, Error = 0.000920
# x = 0.1562, tanh(x) = 0.154991, hardtanh(x) = 0.156250, Error = 0.001259
# x = 0.1719, tanh(x) = 0.170202, hardtanh(x) = 0.171875, Error = 0.001673
# ...
